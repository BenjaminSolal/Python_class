# %% [markdown]
# <a href="https://colab.research.google.com/github/BenjaminSolal/Python_class/blob/main/Copie_de_Copie_de_Copie_de_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import pandas and other dependencies

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pandas as pd
import numpy as np

# %% [markdown]
# # **2)Methodology**

# %% [markdown]
# **2.1 Data acquisition and inspection**

# %%
# loading the dataset
wine_data = pd.read_csv('winequality-red.csv')

# %%
#number of rows and columns
print(wine_data.shape)
#you have 1599 rows and 12 columns
# Out:
# (1599, 12)

# %%
#print the first rows
print(wine_data.head())
#To know how is structured the dataset
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#infos about the dataset
print(wine_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None

# %%
#descriptive statistics
print(wine_data.describe())
#you have the mean, sd, min and max of data that composed each columns.
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# checking for missing values
print(wine_data.isnull().sum())
# No missing value
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# **2.2 Basic Python Programming**

# %%
#Explanation
#check the quality of wine
#Parameters: quality --> quality of the wine, threshold --> the default parameter to define good quality (superior or egal to 7)
# Conditional test. If the quality >= 7, it will print the result "high_quality" or else the result "low_quality"
def chek_wine_quality(quality, quality_threshold = 7):
    if quality >= quality_threshold:
        return 'high_quality'
    else:
        return 'low_quality'

result = chek_wine_quality(5)
print(result)
# Out:
# low_quality

# %%
#explanation
# Define the quality threshold if a wine is considered ‘high quality’ its score has to be superior or equal to 7

# Initialise a dictionary to count wines
# The `wine_quality_count` dictionary will store the number of high quality wines and low_quality wines.

# Browse the data in the df
# For each row in the ‘quality’ column, check whether the score exceeds the threshold (7).
# If it does, we increment the ‘high_quality’ counter, otherwise we increment ‘low_quality’.

import pandas as pd

wine_data = pd.read_csv('winequality-red.csv')


print(wine_data.columns)

quality_threshold = 7


wine_quality_count = {'high_quality': 0, 'low_quality': 0}


for quality in wine_data ['quality']:
    if quality >= quality_threshold:
        wine_quality_count['high_quality'] += 1
    else:
        wine_quality_count['low_quality'] += 1


print("Wine count by quality :", wine_quality_count)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
# Wine count by quality : {'high_quality': 217, 'low_quality': 1382}

# %% [markdown]
# **2.3) Data Cleaning**

# %%
#Load dataset and print the first rows to see the structure of dataset
import pandas as pd
wine_quality = pd.read_csv('winequality-red.csv')
print(wine_quality.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#Inspection
#Show basic infos like the col names and types of data
# Show the mean, sd, min and max value
# show the count of null value for each col
print(wine_quality.info())
print(wine_quality.describe())
print(wine_quality.isnull().sum(  ))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# ...

# %% [markdown]
# Clean the dataset by handling missing values and duplicates.

# %%
# If I've missing values inside my dataset I can remove them or fill them with appropriate values
wine_cleaned = wine_quality.dropna()
#I've dropped rows with missing values

print(wine_cleaned.isnull().sum())
# I want to be sure there are not missing values anymore, and it's good
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Or I could fil out the missing value by certain value like the mean
wine_cleaned = wine_quality.fillna(wine_quality.mean())
print(wine_cleaned.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Duplicated rows. Check and remove them
wine_cleaned = wine_quality.drop_duplicates()
print(f"Number of duplicate rows: {wine_cleaned.duplicated().sum()}")

#There is not duplicated row in the database
# Out:
# Number of duplicate rows: 0

# %%
# sum
# Compute the total of wine
total_wine = wine_cleaned.shape[0]
print(f"Total number of wine: {total_wine}")
#My sample is composed by 1359 wines
# Out:
# Total number of wine: 1359

# %%
# filter data
# I want to find the high quality wine, so I've filtered them and print the five first
hig_quality_wine = wine_cleaned[wine_cleaned['quality'] >= 7]
print(hig_quality_wine.head())
# And I want to know the number of them
print(f"Number of high quality wine: {hig_quality_wine.shape[0]}")
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7             7.3              0.65         0.00             1.2      0.065
# 8             7.8              0.58         0.02             2.0      0.073
# 16            8.5              0.28         0.56             1.8      0.092
# 37            8.1              0.38         0.28             2.1      0.066
# 62            7.5              0.52         0.16             1.9      0.085
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 16                 35.0                 103.0   0.9969  3.30       0.75
# 37                 13.0                  30.0   0.9968  3.23       0.73
# 62                 12.0                  35.0   0.9968  3.38       0.62
#
#     alcohol  quality
# 7      10.0        7
# 8       9.5        7
# ...

# %% [markdown]
# **2.4) Data manipulation**

# %%
#Sort data
# Sort wines by alcohol level in descending order
sorted_wines = wine_cleaned.sort_values(by='alcohol', ascending=False)
print(sorted_wines.head())
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652            15.9              0.36         0.65             7.5      0.096
# 1270            5.0              0.38         0.01             1.6      0.048
# 588             5.0              0.42         0.24             2.0      0.060
# 467             8.8              0.46         0.45             2.6      0.065
# 821             4.9              0.42         0.00             2.1      0.048
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 652                  22.0                  71.0  0.99760  2.98       0.84
# 1270                 26.0                  60.0  0.99084  3.70       0.75
# 588                  19.0                  50.0  0.99170  3.72       0.74
# 467                   7.0                  18.0  0.99470  3.32       0.79
# 821                  16.0                  42.0  0.99154  3.71       0.74
#
#       alcohol  quality
# 652      14.9        5
# ...

# %%
#Group data
# I want to know the average alcohol level according to the quality of wine. So I use the groupby fonction.
average_alcohol_per_quality = wine_cleaned.groupby('quality')['alcohol'].mean()
print(average_alcohol_per_quality)
# Out:
# quality
# 3     9.955000
# 4    10.265094
# 5     9.888562
# 6    10.658879
# 7    11.491118
# 8    12.158824
# Name: alcohol, dtype: float64

# %%
#average
# compute the average alcohol level
average_alcohol = wine_cleaned['alcohol'].mean()
print(f"Average alcohol: {average_alcohol}")
#The average of this sample is below the average for a red wine (around 12-14%)

#compute the average quality
average_quality = wine_cleaned ['quality'].mean()
print(f"Average quality: {average_quality}")
#The average quality is 5.6, it's means that on average a wine is low-quality because I've chosen 7 as minimum to be considered as high-quality
# Out:
# Average alcohol: 10.432315428010792
# Average quality: 5.6232523914643116

# %%
# Maximum and minimum
#find maximum and minimum fixed alcohol level
max_alcohol = wine_cleaned['alcohol'].max()
min_alcohol = wine_cleaned['alcohol'].min()
print(f"Maximum alcohol: {max_alcohol}")
print(f"Minimum alcohol: {min_alcohol}")
# Out:
# Maximum alcohol: 14.9
# Minimum alcohol: 8.4

# %%
#Mean and median of parameters
#fixed acidity
mean_fixed_acidity = wine_cleaned['fixed acidity'].mean()
median_fixed_acidity = wine_cleaned['fixed acidity'].median()
print(f"Mean fixed acidity: {mean_fixed_acidity}")
print(f"Median fixed acidity: {median_fixed_acidity}")

#volatile acidity
mean_volatile_acidity = wine_cleaned['volatile acidity'].mean()
median_volatile_acidity = wine_cleaned['volatile acidity'].median()
print(f"Mean volatile acidity: {mean_volatile_acidity}")
print(f"Median volatile acidity: {median_volatile_acidity}")

#citric acid
mean_citric_acid = wine_cleaned['citric acid'].mean()
median_citric_acid = wine_cleaned['citric acid'].median()
print(f"Mean citric acid: {mean_citric_acid}")
print(f"Median citric acid: {median_citric_acid}")

#residual sugar
mean_residual_sugar = wine_cleaned['residual sugar'].mean()
median_residual_sugar = wine_cleaned['residual sugar'].median()
print(f"Mean residual sugar: {mean_residual_sugar}")
print(f"Median residual sugar: {median_residual_sugar}")

# chlorides
mean_chlorides = wine_cleaned['chlorides'].mean()
median_chlorides = wine_cleaned['chlorides'].median()
print(f"Mean chlorides: {mean_chlorides}")
print(f"Median chlorides: {median_chlorides}")

# free sulfu dioxide
mean_free_sulfur = wine_cleaned['free sulfur dioxide'].mean()
meadian_free_sulfur = wine_cleaned['free sulfur dioxide'].median()
print(f"Mean free sulfur dioxide: {mean_free_sulfur}")
print(f"Median free sulfur dioxide: {meadian_free_sulfur}")

# total sulfur doxide
mean_total_sulfur = wine_cleaned['total sulfur dioxide'].mean()
median_total_sulfur = wine_cleaned['total sulfur dioxide'].median()
print(f"Mean total sulfur dioxide: {mean_total_sulfur}")
print(f"Median total sulfur dioxide: {median_total_sulfur}")

# density
mean_density = wine_cleaned['density'].mean()
median_density = wine_cleaned['density'].median()
print(f"Mean density: {mean_density}")
print(f"Median density: {median_density}")

# pH
mean_pH = wine_cleaned['pH'].mean()
median_pH = wine_cleaned['pH'].median()
print(f"Mean pH: {mean_pH}")
print(f"Median pH: {median_pH}")

#sulphates
mean_sulphates = wine_cleaned['sulphates'].mean()
median_sulphates = wine_cleaned['sulphates'].median()
print(f"Mean sulphates: {mean_sulphates}")
print(f"Median sulphates: {median_sulphates}")

#alcohol
mean_alcohol = wine_cleaned['alcohol'].mean()
median_alcohol = wine_cleaned['alcohol'].median()
print(f"Mean alcohol: {mean_alcohol}")
print(f"Median alcohol: {median_alcohol}")
# Out:
# Mean fixed acidity: 8.310596026490067
# Median fixed acidity: 7.9
# Mean volatile acidity: 0.5294775570272259
# Median volatile acidity: 0.52
# Mean citric acid: 0.2723325974981604
# Median citric acid: 0.26
# Mean residual sugar: 2.5233995584988964
# Median residual sugar: 2.2
# Mean chlorides: 0.08812362030905076
# Median chlorides: 0.079
# Mean free sulfur dioxide: 15.893303899926417
# Median free sulfur dioxide: 14.0
# Mean total sulfur dioxide: 46.82597498160412
# Median total sulfur dioxide: 38.0
# Mean density: 0.9967089477557026
# Median density: 0.9967
# Mean pH: 3.309786607799853
# Median pH: 3.31
# Mean sulphates: 0.6587049300956587
# Median sulphates: 0.62
# Mean alcohol: 10.432315428010792
# Median alcohol: 10.2

# %% [markdown]
# Organise the mean and median into a table to make it more understantable

# %%
data = {
    'Parameters': [
        'Fixed Acidity', 'Volatile Acidity', 'Citric Acid', 'Residual Sugar',
        'Chlorides', 'Free Sulfur Dioxide', 'Total Sulfur Dioxide',
        'Density', 'pH', 'Sulphates', 'Alcohol'
    ],
    'Mean': [
        8.31, 0.53, 0.27, 2.52, 0.09, 15.89, 46.83,
        0.99, 3.31, 0.66, 10.43
    ],
    'Median': [
        7.9, 0.52, 0.26, 2.2, 0.08, 14.0, 38.0,
        0.99, 3.31, 0.62, 10.2
    ]
}
df_stats = pd.DataFrame(data)
print(df_stats)
# Out:
#               Parameters   Mean  Median
# 0          Fixed Acidity   8.31    7.90
# 1       Volatile Acidity   0.53    0.52
# 2            Citric Acid   0.27    0.26
# 3         Residual Sugar   2.52    2.20
# 4              Chlorides   0.09    0.08
# 5    Free Sulfur Dioxide  15.89   14.00
# 6   Total Sulfur Dioxide  46.83   38.00
# 7                Density   0.99    0.99
# 8                     pH   3.31    3.31
# 9              Sulphates   0.66    0.62
# 10               Alcohol  10.43   10.20

# %%
#percentage of high quality wine
high_quality_percentage = len(wine_cleaned[wine_cleaned['quality'] >= 7]) / len(wine_cleaned) * 100
print(f"Proportion of high-quality wine : {high_quality_percentage:.2f}%")
# Out:
# Proportion of high-quality wine : 13.54%

# %%
#segmentation by quality
def segment_quality(quality):
    if quality >= 7:
        return 'High Quality'
    elif quality == 6:
      return 'Medium Quality'
    else:
        return 'Low Quality'

wine_cleaned['Quality Segment'] = wine_cleaned['quality'].apply(segment_quality)
print(wine_cleaned[['quality', 'Quality Segment']].head())
# Out:
#    quality Quality Segment
# 0        5     Low Quality
# 1        5     Low Quality
# 2        5     Low Quality
# 3        6  Medium Quality
# 5        5     Low Quality
# <ipython-input-82-003234b64394>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_cleaned['Quality Segment'] = wine_cleaned['quality'].apply(segment_quality)

# %%
#Segmentation by alcohol level
#
wine_cleaned['Alcohol Segment'] = pd.cut(wine_cleaned['alcohol'],
                                         bins=[0, 10, 12, 15],
                                         labels=['Low Alcohol', 'Moderate Alcohol', 'High Alcohol'])

print(wine_cleaned[['alcohol', 'Alcohol Segment']].head())
# Out:
#    alcohol Alcohol Segment
# 0      9.4     Low Alcohol
# 1      9.8     Low Alcohol
# 2      9.8     Low Alcohol
# 3      9.8     Low Alcohol
# 5      9.4     Low Alcohol
# <ipython-input-83-2ea84487987f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_cleaned['Alcohol Segment'] = pd.cut(wine_cleaned['alcohol'],

# %% [markdown]
# **2.5) Correlation**

# %%
# Select only numeric columns
numeric_columns = wine_cleaned.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation of each parameter with quality
quality_correlation = numeric_columns.corr()['quality'].sort_values(ascending=False)
print("Correlation of each parameter with quality:")
print(quality_correlation)
# Out:
# Correlation of each parameter with quality:
# quality                 1.000000
# alcohol                 0.480343
# sulphates               0.248835
# citric acid             0.228057
# fixed acidity           0.119024
# residual sugar          0.013640
# free sulfur dioxide    -0.050463
# pH                     -0.055245
# chlorides              -0.130988
# total sulfur dioxide   -0.177855
# density                -0.184252
# volatile acidity       -0.395214
# Name: quality, dtype: float64

# %% [markdown]
# ***2.6) Data vizualisation. ***
# I've done some vizualisation of data to have a better look at some relations.
# I've used several tools like Bar chart, Heat map and scatter plot.

# %%
#Bar chart
# I want to see the number of wine for each quality scores
# the horizontal axis is the quality of wine, the vertical one represent the count of wine
# count the number of wines for each quality score
quality_counts = wine_cleaned['quality'].value_counts().sort_index()
#I define the size of the bar, the key element and the color
plt.figure (figsize=(10,6))
plt.bar(quality_counts.index, quality_counts.values, color ="skyblue")

#I define the x axis, the y axis, the title of the chart
plt.xlabel('Quality')
plt.ylabel('Count')
plt.title('Distribution of Wine Quality')
plt.show()

#You can see that the wine is normally distributed, and the quality category that are most represented are 5 and 6, not so good quality for my study.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

segment_counts = wine_cleaned['Alcohol Segment'].value_counts()


plt.figure(figsize=(10, 6))
sns.barplot(x=segment_counts.index, y=segment_counts.values, color ='skyblue')


plt.title('Distribution of alcohol level')
plt.xlabel('Alcohol level')
plt.ylabel('Count')


plt.show()

# %%
#Scatter plot
# I want to see the relation between alcohol level and quality
plt.figure(figsize=(10, 6))
plt.scatter(wine_cleaned['alcohol'], wine_cleaned['quality'],alpha=0.7, color='skyblue')

#Define the axis, the title
plt.xlabel('Quality Score')
plt.ylabel('Alcohol Level')
plt.title('Alcohol Level vs. Quality Score')

#I put a grid in the back, to have a more readable plot
plt.grid(alpha=0.5, linestyle='--')
plt.show()

# %%
#heatmap
# I want to see the relation between alcohol level and the quality of the wine
#I put quality on the rows, the values of the matrix are the alcohol level, aggfunc = mean --> if multiple entries exits for
# a alcohol-quality combinaton, it take the means of alcohol level
heatmap_data = wine_cleaned.pivot_table(values='alcohol', index='quality', aggfunc='mean')
heatmap_data = heatmap_data.reset_index()

# annot=TRUE, displays the levels inside each cell of the heatmap, it's more readable
#fmt=.2F, the level will take 2 decimal points
#cmap ="YlGnBu" it's for the color palette for the graduation from Yellow to Green to Blue, lower to higher
plt.figure(figsize=(10, 6))
sns.heatmap(
    heatmap_data.set_index("quality"),
    annot=True,
    fmt=".2f",
    cmap="YlGnBu" )


plt.title('Average Alcohol Level by Quality Score')
plt.xlabel('Feature')
plt.ylabel('Quality')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="RdYlGn", fmt=".2f")
plt.title("Correlation Matrix of Chemical Properties")
plt.show()

# %%
sns.scatterplot(data=wine_cleaned, x='alcohol', y='quality')
plt.title('Alcohol vs Quality')
plt.show()

sns.scatterplot(data=wine_cleaned, x='volatile acidity', y='quality')
plt.title('Volatile Acidity vs Quality')
plt.show()

# %% [markdown]
# **2.7) SQL Alchemy**

# %%
pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# Define SQLite database URL
db_url = 'sqlite:///wine_quality.db'

# Create a database engine
engine = create_engine(db_url, echo=False)

# Store the cleaned dataset into the database
wine_cleaned.to_sql('wine_quality', engine, if_exists='replace', index=False)

print("Data successfully stored in SQLite database.")
# Out:
# Data successfully stored in SQLite database.

# %%
#Do some query to verify if the SQL works well
#Here I want to see the average alcohol by quality, I've already done that in Python before
query_1 = """
SELECT
    quality,
    AVG(alcohol) AS avg_alcohol
FROM
    wine_quality
GROUP BY
    quality
ORDER BY
    avg_alcohol DESC;
"""

result_1 = pd.read_sql(query_1, engine)
print("Average Alcohol Content by Quality:")
print(result_1)
# Out:
# Average Alcohol Content by Quality:
#    quality  avg_alcohol
# 0        8    12.158824
# 1        7    11.491118
# 2        6    10.658879
# 3        4    10.265094
# 4        3     9.955000
# 5        5     9.888562

# %%
#I want to see what are the 5 strongest wines in term of alcohol level
# And I also want to have the quality of these wines
query_2 = """
SELECT
    quality,
    alcohol
FROM
    wine_quality
ORDER BY
    alcohol DESC
LIMIT 5;
"""

result_2 = pd.read_sql(query_3, engine)
print("Top 5 Wines with the Highest Alcohol Content:")
print(result_2)
# Out:
# Top 5 Wines with the Highest Alcohol Content:
#    quality  alcohol
# 0        5     14.9
# 1        6     14.0
# 2        6     14.0
# 3        8     14.0
# 4        7     14.0
